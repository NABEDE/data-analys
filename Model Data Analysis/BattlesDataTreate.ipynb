# %%
import pandas as pdas
import matplotlib.pyplot as plt

#Collecting data 
data = pdas.read_csv('Dataset/battles.csv')
data
# Out:
#      isqno                               war                name  \
# 0        1  NETHERLAND'S WAR OF INDEPENDENCE            NIEUPORT
# 1        2                 THIRTY YEAR'S WAR      WHITE MOUNTAIN
# 2        3                 THIRTY YEAR'S WAR             WIMPFEN
# 3        4                 THIRTY YEAR'S WAR       DESSAU BRIDGE
# 4        5                 THIRTY YEAR'S WAR              LUTTER
# ..     ...                               ...                 ...
# 655    656                ARAB-ISRAELI, 1948  JERUSALEM CORRIDOR
# 656    657                      WORLD WAR II            ARDENNES
# 657    658                      WORLD WAR II             CAMBRAI
# 658    659                      WORLD WAR II               ARRAS
# 659    660                      WORLD WAR II                BOOS
#
#                  locn                              campgn  postype post1  \
# 0    SPANISH FLANDERS                       NIEUPORT 1600        0    HD
# ...

# %%
#Cleaning data 
data_clean = data.filter(['isqno','war','name', 'locn', 'campgn', 'postype', 'war2', 'war3', 'war4'])
data_clean
# Out:
#      isqno                               war                name  \
# 0        1  NETHERLAND'S WAR OF INDEPENDENCE            NIEUPORT
# 1        2                 THIRTY YEAR'S WAR      WHITE MOUNTAIN
# 2        3                 THIRTY YEAR'S WAR             WIMPFEN
# 3        4                 THIRTY YEAR'S WAR       DESSAU BRIDGE
# 4        5                 THIRTY YEAR'S WAR              LUTTER
# ..     ...                               ...                 ...
# 655    656                ARAB-ISRAELI, 1948  JERUSALEM CORRIDOR
# 656    657                      WORLD WAR II            ARDENNES
# 657    658                      WORLD WAR II             CAMBRAI
# 658    659                      WORLD WAR II               ARRAS
# 659    660                      WORLD WAR II                BOOS
#
#                  locn                              campgn  postype  \
# 0    SPANISH FLANDERS                       NIEUPORT 1600        0
# ...

# %%
#Manipulating data 
isqno = data_clean['isqno']
war = data_clean['war']
name = data_clean['name']
locn = data_clean['locn']
campagn = data_clean['campgn']
postype = data_clean['postype']
war2 = data_clean['war2']
war3 = data_clean['war3']
war4 = data_clean['war4']
# Out:
# 0       Eighty Years War of 1568-1648
# 1      Thirty Years' War of 1618-1648
# 2      Thirty Years' War of 1618-1648
# 3      Thirty Years' War of 1618-1648
# 4      Thirty Years' War of 1618-1648
#                     ...
# 655     Arab-Israeli War of 1948-1949
# 656         World War II of 1939-1945
# 657         World War II of 1939-1945
# 658         World War II of 1939-1945
# 659         World War II of 1939-1945
# Name: war4, Length: 660, dtype: object

# %%
#Analysing 
#That is not number, then we go for visualisation

plt.plot(isqno)

# %%
war.count()
# Out:
# 660

# %%
postype.describe()
# Out:
# count    660.000000
# mean       0.874242
# std        2.317893
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        9.000000
# Name: postype, dtype: float64

# %%
name.count()
# Out:
# 660

# %%
war
# Out:
# 0      NETHERLAND'S WAR OF INDEPENDENCE
# 1                     THIRTY YEAR'S WAR
# 2                     THIRTY YEAR'S WAR
# 3                     THIRTY YEAR'S WAR
# 4                     THIRTY YEAR'S WAR
#                      ...
# 655                  ARAB-ISRAELI, 1948
# 656                        WORLD WAR II
# 657                        WORLD WAR II
# 658                        WORLD WAR II
# 659                        WORLD WAR II
# Name: war, Length: 660, dtype: object

# %%
name
# Out:
# 0                NIEUPORT
# 1          WHITE MOUNTAIN
# 2                 WIMPFEN
# 3           DESSAU BRIDGE
# 4                  LUTTER
#               ...
# 655    JERUSALEM CORRIDOR
# 656              ARDENNES
# 657               CAMBRAI
# 658                 ARRAS
# 659                  BOOS
# Name: name, Length: 660, dtype: object

# %%
locn
# Out:
# 0      SPANISH FLANDERS
# 1               BOHEMIA
# 2            PALATINATE
# 3                ANHALT
# 4             BRUNSWICK
#              ...
# 655           WEST BANK
# 656    NORTHWEST EUROPE
# 657    NORTHWEST EUROPE
# 658    NORTHWEST EUROPE
# 659    NORTHWEST EUROPE
# Name: locn, Length: 660, dtype: object

# %%
campagn
# Out:
# 0                           NIEUPORT 1600
# 1                            BOHEMIA 1620
# 2                         PALATINATE 1622
# 3      DANISH INVASION OF GERMANY 1625-26
# 4      DANISH INVASION OF GERMANY 1625-26
#                       ...
# 655                    JERUSALEM CORRIDOR
# 656                         ARDENNES 1940
# 657                               CAMBRAI
# 658                                 ARRAS
# 659                                  BOOS
# Name: campgn, Length: 660, dtype: object

# %%
war2
# Out:
# 0      NETHERLAND'S WAR OF INDEPENDENCE
# 1                     THIRTY YEAR'S WAR
# 2                     THIRTY YEAR'S WAR
# 3                     THIRTY YEAR'S WAR
# 4                     THIRTY YEAR'S WAR
#                      ...
# 655                  ARAB-ISRAELI, 1948
# 656          WORLD WAR II (FRANCE 1940)
# 657          WORLD WAR II (FRANCE 1940)
# 658          WORLD WAR II (FRANCE 1940)
# 659          WORLD WAR II (FRANCE 1940)
# Name: war2, Length: 660, dtype: object

# %%
war3
# Out:
# 0      NETHERLAND'S WAR OF INDEPENDENCE
# 1                     THIRTY YEAR'S WAR
# 2                     THIRTY YEAR'S WAR
# 3                     THIRTY YEAR'S WAR
# 4                     THIRTY YEAR'S WAR
#                      ...
# 655                  ARAB-ISRAELI, 1948
# 656                        WORLD WAR II
# 657                        WORLD WAR II
# 658                        WORLD WAR II
# 659                        WORLD WAR II
# Name: war3, Length: 660, dtype: object

# %%
war4
# Out:
# 0       Eighty Years War of 1568-1648
# 1      Thirty Years' War of 1618-1648
# 2      Thirty Years' War of 1618-1648
# 3      Thirty Years' War of 1618-1648
# 4      Thirty Years' War of 1618-1648
#                     ...
# 655     Arab-Israeli War of 1948-1949
# 656         World War II of 1939-1945
# 657         World War II of 1939-1945
# 658         World War II of 1939-1945
# 659         World War II of 1939-1945
# Name: war4, Length: 660, dtype: object

# %%
war4F = pdas.DataFrame(war4)
war4F
# Out:
#                                war4
# 0     Eighty Years War of 1568-1648
# 1    Thirty Years' War of 1618-1648
# 2    Thirty Years' War of 1618-1648
# 3    Thirty Years' War of 1618-1648
# 4    Thirty Years' War of 1618-1648
# ..                              ...
# 655   Arab-Israeli War of 1948-1949
# 656       World War II of 1939-1945
# 657       World War II of 1939-1945
# 658       World War II of 1939-1945
# 659       World War II of 1939-1945
#
# [660 rows x 1 columns]
